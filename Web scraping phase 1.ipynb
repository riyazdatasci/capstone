# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
search = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/li[1]/a')
search.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
property_url
# Out:
# ['https://www.olx.in/item/house-for-rent-iid-1757342899',
#  'https://www.olx.in/item/full-appartement-for-lease-iid-1761665150',
#  'https://www.olx.in/item/sk-apartment-for-rent-at-thripoonithura-iid-1711751731',
#  'https://www.olx.in/item/fully-furnished-premium-studio-apartment-for-girls-iid-1762361410',
#  'https://www.olx.in/item/rent-house-at-edappally-iid-1762361387',
#  'https://www.olx.in/item/2bhk-fully-furnished-willa-ground-floor-iid-1762361328',
#  'https://www.olx.in/item/3bhk-semi-furnished-apartmentflat-for-rent-close-to-vytilla-junction-iid-1761092953',
#  'https://www.olx.in/item/3-bed-room-new-house-for-rent-iid-1742807749',
#  'https://www.olx.in/item/2bhk-furnished-willa-1st-floor-iid-1762361062',
#  'https://www.olx.in/item/2-bedroom-fully-furnished-first-floor-apartment-near-kaloorkochi-iid-1761596414',
#  'https://www.olx.in/item/upstair-for-rent-home-iid-1762360430',
#  'https://www.olx.in/item/house-for-rent-iid-1762360339',
# ...

# %%
for url in property_url:
    driver.get(url)
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32304\4151521552.py in <module>
#       1 for url in property_url:
# ----> 2     driver.get(url)
#       3
#       4
#       5     try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     351     def get(self, url: str) -> None:
#     352         """Loads a web page in the current browser session."""
# --> 353         self.execute(Command.GET, {"url": url})
#     354
#     355     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
# ...

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (593, 593, 593, 593, 593, 593, 593, 593, 593, 593, 593, 592)

# %%
df1 = pd.DataFrame({})
df1[' Rental Price']=Price[0:590]
df1['Address']=Address[0:590]
df1['City']=City[0:590]
df1['Bedrooms']=Bedrooms[0:590]
df1['Bathrooms']=Bathrooms[0:590]
df1['Total floors']=Total_floors[0:590]
df1['Car parking']=Car_parking[0:590]
df1['Bachelors allowed']=Bachelors_allowed[0:590]   
df1['Area']=Area[0:590]
df1['Furnishing']=Furnishing[0:590]
df1['Type']=Type[0:590]
df1['Maintenance']=Maintenance[0:590]
df1
# Out:
#      Rental Price                                            Address  \
# 0        ₹ 13,000                    1 BHK FULLY FURNISHED NEW FLAT.
# 1        ₹ 13,000                            2bhk available for rent
# 2        ₹ 24,100                              2bhk near saket metro
# 3        ₹ 22,000                        1bhk builder floor in saket
# 4        ₹ 15,000                   Near tagore garden metro station
# ..            ...                                                ...
# 585       ₹ 6,000  Instant shifting available furnished house ren...
# 586       ₹ 7,000  Couples friendly ground floor new condition 1b...
# 587       ₹ 3,500  No restrictions 1Rk 2nd floor furnished rent i...
# 588      ₹ 13,000      Full furnished 1bhk flat available for rent .
# 589       ₹ 5,000                  New one bhk flat rent in new town
#
#             City Bedrooms  Bathrooms Total floors   Car parking  \
# 0          Delhi        3          2            3             0
# ...

# %%
driver.quit()

# %% [markdown]
# # city 2

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
search = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/li[2]/a')
search.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    time.sleep(1)
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400)

# %%
df2 = pd.DataFrame({})
df2[' Rental Price']=Price
df2['Address']=Address
df2['City']=City
df2['Bedrooms']=Bedrooms
df2['Bathrooms']=Bathrooms
df2['Total floors']=Total_floors
df2['Car parking']=Car_parking
df2['Bachelors allowed']=Bachelors_allowed   
df2['Area']=Area
df2['Furnishing']=Furnishing
df2['Type']=Type
df2['Maintenance']=Maintenance
df2
# Out:
#      Rental Price                                            Address  \
# 0         ₹ 9,000                      Helloworld Elegant - Coliving
# 1        ₹ 39,999  3bhk Fully furnished flat with allotted car pa...
# 2        ₹ 14,499                      Affordable 1bhk @ 14499/-only
# 3        ₹ 32,000                        3 BHK flat for rent in ulwe
# 4        ₹ 30,000           2BHK for rent Nearby eon it park kharadi
# ..            ...                                                ...
# 395      ₹ 21,000                  2Bhk in Kharghar Unfurnished Flat
# 396      ₹ 20,000                  2Bhk in Kharghar Unfurnished Flat
# 397      ₹ 17,000                  1Bhk in Kharghar Unfurnished Flat
# 398      ₹ 28,000                    2Bhk in Roadpali Furnished Flat
# 399      ₹ 23,000                        2Bhk in Ulwe Furnished Flat
#
#             City Bedrooms Bathrooms Total floors Car parking  \
# 0    Maharashtra        1         1            2        East
# ...

# %%
driver.quit()

# %% [markdown]
# # city 3

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
search = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/li[3]/a')
search.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    time.sleep(1)
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')

# %%
df3 = pd.DataFrame({})
df3[' Rental Price']=Price
df3['Address']=Address
df3['City']=City
df3['Bedrooms']=Bedrooms
df3['Bathrooms']=Bathrooms
df3['Total floors']=Total_floors
df3['Car parking']=Car_parking
df3['Bachelors allowed']=Bachelors_allowed   
df3['Area']=Area
df3['Furnishing']=Furnishing
df3['Type']=Type
df3['Maintenance']=Maintenance
df3
# Out:
#      Rental Price                                            Address  \
# 0        ₹ 12,000          Beautiful newly constructed home for rent
# 1         ₹ 9,000  2 bhk flat in Vivekpuram Colony, Shivpur for rent
# 2        ₹ 11,000  भोजूवीर अर्दली बाजार में किसी भी आयोजन के लिए ...
# 3        ₹ 14,500                            3bhk available for rent
# 4        ₹ 13,999                         2bhk Unfrenished available
# ..            ...                                                ...
# 395      ₹ 12,000       Excellent Flat in prominent society for rent
# 396       ₹ 4,000           NEED FEMALE ROOMMATE AND 2 ALREADY THERE
# 397       ₹ 8,000  1 bhk independent flats available for Family, ...
# 398      ₹ 28,000                               flat for rent family
# 399      ₹ 55,000                             3bhk+ 1 flat for lease
#
#               City Bedrooms Bathrooms Total floors  \
# 0    Uttar Pradesh        2         1            1
# ...

# %%
driver.close()

# %% [markdown]
# # city 4

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
city_gujrat = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/div/li[1]/a')
city_gujrat.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32304\1249007436.py in <module>
#       4     try:
#       5         prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
# ----> 6         Name.append(prop_name.text)
#       7     except NoSuchElementException:
#       8         Name.append('NA')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (486, 486, 486, 486, 486, 486, 486, 486, 486, 486, 486, 486)

# %%
df4 = pd.DataFrame({})
df4[' Rental Price']=Price
df4['Address']=Address
df4['City']=City
df4['Bedrooms']=Bedrooms
df4['Bathrooms']=Bathrooms
df4['Total floors']=Total_floors
df4['Car parking']=Car_parking
df4['Bachelors allowed']=Bachelors_allowed   
df4['Area']=Area
df4['Furnishing']=Furnishing
df4['Type']=Type
df4['Maintenance']=Maintenance
df4
# Out:
#      Rental Price                                            Address     City  \
# 0        ₹ 14,000  2BHK Semi Furnished Flat for Rent in New CG Ro...  Gujarat
# 1        ₹ 18,000  2bhk fully furnished flat for rent Sharvan Cho...  Gujarat
# 2        ₹ 20,000           Furnished flat on rent in althan bhimrad  Gujarat
# 3        ₹ 11,000                                  2BHK flat on rent  Gujarat
# 4         ₹ 9,500                2 Bhk Semi Furnished Flat in Vadsar  Gujarat
# ..            ...                                                ...      ...
# 481       ₹ 8,500                 1bhk @SHRVAN CHOKDI FAMILY CALL us  Gujarat
# 482      ₹ 11,500  Nice 1bhk flat rent vandematram road gota ahme...  Gujarat
# 483       ₹ 7,000                                     Flat available  Gujarat
# 484       ₹ 7,800                                     Renovated flat  Gujarat
# 485      ₹ 13,000                                  I want rent house  Gujarat
#
# ...

# %%
driver.quit()

# %% [markdown]
# # city 5

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
city_punjab = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/li[5]/a')
city_punjab.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400)

# %%
df5 = pd.DataFrame({})
df5[' Rental Price']=Price
df5['Address']=Address
df5['City']=City
df5['Bedrooms']=Bedrooms
df5['Bathrooms']=Bathrooms
df5['Total floors']=Total_floors
df5['Car parking']=Car_parking
df5['Bachelors allowed']=Bachelors_allowed   
df5['Area']=Area
df5['Furnishing']=Furnishing
df5['Type']=Type
df5['Maintenance']=Maintenance
df5
# Out:
#      Rental Price                                            Address  \
# 0         ₹ 6,000  1 BHK Fully Furnished Room For MNC / Bank Empl...
# 1         ₹ 9,000  (*For Girls only*) Fully Furnished 1RK Studio ...
# 2        ₹ 18,000              2 - 3 bhk semi available in la prisma
# 3        ₹ 12,000            2 bedroom attach kitchen bath phase 3b2
# 4              NA                                                 NA
# ..            ...                                                ...
# 395      ₹ 20,000  Independet apartment 2 bhk fully furnished at ...
# 396      ₹ 10,000   2 bedroom set ground floor at urban estate dugri
# 397      ₹ 11,000      1 bedroom kitchen washroom at model town extn
# 398      ₹ 13,000   2 bedroom set at urban estate dugri ground floor
# 399      ₹ 22,000  2 bedroom set first floor furnished at model T...
#
#             City Bedrooms Bathrooms Total floors  \
# 0         Punjab        1         1            1
# ...

# %%
driver.close()

# %% [markdown]
# # city 6

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
city_delhi = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/div/li[4]/a')
city_delhi.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    time.sleep(1)
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400)

# %%
df6 = pd.DataFrame({})
df6[' Rental Price']=Price
df6['Address']=Address
df6['City']=City
df6['Bedrooms']=Bedrooms
df6['Bathrooms']=Bathrooms
df6['Total floors']=Total_floors
df6['Car parking']=Car_parking
df6['Bachelors allowed']=Bachelors_allowed   
df6['Area']=Area
df6['Furnishing']=Furnishing
df6['Type']=Type
df6['Maintenance']=Maintenance
df6
# Out:
#      Rental Price                                            Address   City  \
# 0        ₹ 13,000                    1 BHK FULLY FURNISHED NEW FLAT.  Delhi
# 1        ₹ 13,000                            2bhk available for rent  Delhi
# 2        ₹ 24,100                              2bhk near saket metro  Delhi
# 3        ₹ 22,000                        1bhk builder floor in saket  Delhi
# 4        ₹ 15,000                   Near tagore garden metro station  Delhi
# ..            ...                                                ...    ...
# 395      ₹ 15,000  2BHK BREND NEW BEAUTIFUL FLAT FOR RENT IN SAKE...  Delhi
# 396      ₹ 27,000        Dhruv gohri! 3 bhk floor available for rent  Delhi
# 397      ₹ 22,000  2bhk Flat for rent in freedom fighter enclave ...  Delhi
# 398      ₹ 25,000                  2 Bhk flatFitderm fighter enclave  Delhi
# 399      ₹ 16,000                   1Bhk flat for Paryavaran complex  Delhi
#
# ...

# %%
driver.close()

# %% [markdown]
# # city 7

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
city_MP = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/div/li[3]/a')
city_MP.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    time.sleep(1)
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32304\1155758197.py in <module>
#       5     try:
#       6         prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
# ----> 7         Name.append(prop_name.text)
#       8     except NoSuchElementException:
#       9         Name.append('NA')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      87     def text(self) -> str:
#      88         """The text of the element."""
# ---> 89         return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#      90
#      91     def click(self) -> None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     392             params = {}
# ...

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (540, 540, 540, 540, 540, 540, 540, 540, 540, 540, 540, 540)

# %%
df7 = pd.DataFrame({})
df7[' Rental Price']=Price
df7['Address']=Address
df7['City']=City
df7['Bedrooms']=Bedrooms
df7['Bathrooms']=Bathrooms
df7['Total floors']=Total_floors
df7['Car parking']=Car_parking
df7['Bachelors allowed']=Bachelors_allowed   
df7['Area']=Area
df7['Furnishing']=Furnishing
df7['Type']=Type
df7['Maintenance']=Maintenance
df7
# Out:
#      Rental Price                                            Address  \
# 0        ₹ 15,000                1bhk full furnished and unfurnished
# 1        ₹ 10,000            2 BHK portion on rent for Govt Officers
# 2         ₹ 3,000  1RK2500 ||1RK 3000|| 2Rk4000 ||rent Ratahara b...
# 3        ₹ 15,000  CALL FOR LUXURIOUS 1BHK FULLY FURNISHED FLAT F...
# 4         ₹ 2,000       1 room kitchen stand latebath only for girls
# ..            ...                                                ...
# 535       ₹ 4,500                                    Rent par dena h
# 536      ₹ 10,000                                    1 bhk for girls
# 537      ₹ 12,000                   1 bhk indipendent semi furnished
# 538       ₹ 9,500                                     House for rent
# 539      ₹ 15,000                1bhk full furnished and unfurnished
#
#                City Bedrooms Bathrooms Total floors Car parking  \
# 0    Madhya Pradesh        1         1            5           1
# ...

# %%
driver.close()

# %% [markdown]
# # City 8

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
city_haryana = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/div/li[6]/a')
city_haryana.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
len(property_url)
# Out:
# 400

# %%
for url in property_url:
    driver.get(url)
    
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32304\550145195.py in <module>
#       4
#       5     try:
# ----> 6         prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
#       7         Name.append(prop_name.text)
#       8     except NoSuchElementException:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ...

# %%
df8 = pd.DataFrame({})
df8[' Rental Price']=Price
df8['Address']=Address
df8['City']=City
df8['Bedrooms']=Bedrooms
df8['Bathrooms']=Bathrooms
df8['Total floors']=Total_floors
df8['Car parking']=Car_parking
df8['Bachelors allowed']=Bachelors_allowed   
df8['Area']=Area
df8['Furnishing']=Furnishing
df8['Type']=Type
df8['Maintenance']=Maintenance
df8
# Out:
#      Rental Price                                            Address     City  \
# 0        ₹ 13,500  Semi furnished 1 BHK available for rent in a g...  Haryana
# 1        ₹ 15,000                                 GROUND FLOOR 2 BHK  Haryana
# 2        ₹ 28,000  Super Spacious fully Furnished 3 bhk flat for ...  Haryana
# 3        ₹ 13,500       2 bhk flat new society good location to stay  Haryana
# 4         ₹ 2,500                                    One room patner  Haryana
# ..            ...                                                ...      ...
# 397       ₹ 1,400                                      Only for boys  Haryana
# 398       ₹ 3,400                                      Room for rent  Haryana
# 399      ₹ 18,000                             1bhk Furnished on Rent  Haryana
# 400      ₹ 13,500  Semi furnished 1 BHK available for rent in a g...  Haryana
# 401      ₹ 15,000                                 GROUND FLOOR 2 BHK  Haryana
#
# ...

# %%
driver.close()

# %% [markdown]
# # City 9

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
city_AP = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/div/li[9]/a')
city_AP.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32304\550145195.py in <module>
#       4
#       5     try:
# ----> 6         prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
#       7         Name.append(prop_name.text)
#       8     except NoSuchElementException:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ...

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (440, 440, 440, 440, 440, 440, 440, 440, 440, 440, 440, 440)

# %%
df9 = pd.DataFrame({})
df9[' Rental Price']=Price
df9['Address']=Address
df9['City']=City
df9['Bedrooms']=Bedrooms
df9['Bathrooms']=Bathrooms
df9['Total floors']=Total_floors
df9['Car parking']=Car_parking
df9['Bachelors allowed']=Bachelors_allowed   
df9['Area']=Area
df9['Furnishing']=Furnishing
df9['Type']=Type
df9['Maintenance']=Maintenance
df9
# Out:
#      Rental Price                                            Address  \
# 0         ₹ 9,000  2BHK Property with Curtain Rods, Cloth Drying ...
# 1         ₹ 8,500  2BHK ground & 2nd floor 4r rent behind KBR Sch...
# 2         ₹ 5,500                                     House for rent
# 3         ₹ 7,500             Good ventilation , full cupboard work,
# 4        ₹ 18,000                                  On Monthly Rental
# ..            ...                                                ...
# 435      ₹ 35,000                               Flat for rent-₹35000
# 436       ₹ 4,300           Pent House for Rent - Only for Bachelors
# 437       ₹ 5,400  Individual 1st floor for rent to vegetarian fa...
# 438       ₹ 4,000                       Home for family or Bachelors
# 439       ₹ 8,500  2 BHK INDIVIDUAL HOUSE AVAILABLE FOR RENT . EA...
#
#                City Bedrooms Bathrooms Total floors Car parking  \
# 0    Andhra Pradesh        2         2            2           1
# ...

# %%
driver.close()

# %% [markdown]
# # City 10

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
city_haryana = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/div/li[2]/a')
city_haryana.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32304\550145195.py in <module>
#       4
#       5     try:
# ----> 6         prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
#       7         Name.append(prop_name.text)
#       8     except NoSuchElementException:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ...

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (401, 401, 401, 401, 401, 401, 401, 401, 401, 401, 401, 401)

# %%
df10 = pd.DataFrame({})
df10[' Rental Price']=Price
df10['Address']=Address
df10['City']=City
df10['Bedrooms']=Bedrooms
df10['Bathrooms']=Bathrooms
df10['Total floors']=Total_floors
df10['Car parking']=Car_parking
df10['Bachelors allowed']=Bachelors_allowed   
df10['Area']=Area
df10['Furnishing']=Furnishing
df10['Type']=Type
df10['Maintenance']=Maintenance
df10
# Out:
#      Rental Price                                            Address  \
# 0     ₹ 15,00,000                    LEASE ONLY 1 RK Pent House Room
# 1     ₹ 43,50,000  Lease house in Apartment (3BHK) with luxury am...
# 2     ₹ 12,00,000                                      1BHK for Rent
# 3        ₹ 10,000                             Brand New Flat on Rent
# 4        ₹ 23,000                      1-BHK with available for rent
# ..            ...                                                ...
# 396       ₹ 9,000     Vijayaganar 2nd stage house for rent in ground
# 397      ₹ 11,000  Vijayaganar 2nd stage house for rent in ground...
# 398      ₹ 12,500  Vijayaganar 2nd stage house for rent in 1st floor
# 399       ₹ 5,500  Hebbal 2nd stage house for Room rent in 1st floor
# 400   ₹ 15,00,000                    LEASE ONLY 1 RK Pent House Room
#
#           City Bedrooms Bathrooms Total floors Car parking Bachelors allowed  \
# ...

# %%
driver.close()

# %% [markdown]
# # city 11

# %%
driver = webdriver.Chrome()
driver.get('https://www.olx.in/')

# %%
Rent = driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div/div/div[1]/div[2]/div[7]/a/span')
Rent.click()

# %%
city_bengal = driver.find_element(By.XPATH,'//*[@id="main_content"]/div/div/section/div/div/div[5]/div[1]/div/div/div[2]/div[3]/ul/li/ul/div/li[7]/a')
city_bengal.click()

# %%
Name = []
Price = []
Address = []
City = []
Area = []
Bedrooms = []
Bathrooms = []
Carpet_area = []
Total_floors = []
Car_parking = []
Bachelors_allowed = []
Furnishing = []
Type = []
Facing = []
Maintenance =[]

# %%
property_url = []
start = 0
end = 10
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//li[@class="_1DNjI"]//a')
    for i in url:
        property_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[1]/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')

# %%
for url in property_url:
    driver.get(url)
    
    
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try: 
        price = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[1]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('NA')
        
        
    try: 
        prop_name = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/span[2]')
        Name.append(prop_name.text)
    except NoSuchElementException:
        Name.append('NA')
        
        
    try:
        city = driver.find_element(By.XPATH, '/html/body/div/div/header/div/div/div[2]/div/div/div[1]/div/div[1]/input')
        City.append(city.get_attribute('value'))
    except NoSuchElementException:
        City.append('not present')
        
        
    try: 
        address = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[5]/div[1]/div/section/h1')
        Address.append(address.text)
    except NoSuchElementException:
        Address.append('NA')
        
        
    try: 
        area = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[6]/div/span[2]')
        Area.append(area.text)
    except NoSuchElementException:
        Area.append('NA')
        
        
    try: 
        bedroom = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[2]/div/span[2]')
        Bedrooms.append(bedroom.text)
    except NoSuchElementException:
        Bedrooms.append('NA')
        
        
    try: 
        bath = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[3]/div/span[2]')
        Bathrooms.append(bath.text)
    except NoSuchElementException:
        Bathrooms.append('NA')
        
        
    try: 
        floors = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[10]/div/span[2]')
        Total_floors.append(floors.text)
    except NoSuchElementException:
        Total_floors.append('NA')
        
        
    try: 
        parking = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[12]/div/span[2]')
        Car_parking.append(parking.text)
    except NoSuchElementException:
        Car_parking.append('NA')
        
        
    try: 
        bachelors= driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[8]/div/span[2]')
        Bachelors_allowed.append(bachelors.text)
    except NoSuchElementException:
        Bachelors_allowed.append('NA')
        
        
    try: 
        furnishing = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[4]/div/span[2]')
        Furnishing.append(furnishing.text)
    except NoSuchElementException:
        Furnishing.append('NA')
        
        
    try: 
        type_ = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[1]/div/span[2]')
        Type.append(type_.text)
    except NoSuchElementException:
        Type.append('NA')
        
        
    try: 
        maintenance = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/div/div/div[4]/section/div/div/div[1]/div/div[9]/div/span[2]')
        Maintenance.append(maintenance.text)
    except NoSuchElementException:
        Maintenance.append('NA')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32304\550145195.py in <module>
#       1 for url in property_url:
# ----> 2     driver.get(url)
#       3
#       4
#       5     try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     351     def get(self, url: str) -> None:
#     352         """Loads a web page in the current browser session."""
# --> 353         self.execute(Command.GET, {"url": url})
#     354
#     355     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
# ...

# %%
len(Price),len(Address),len(City),len(Bedrooms),len(Bathrooms),len(Total_floors),len(Car_parking),len(Bachelors_allowed),len(Area),len(Furnishing),len(Type),len(Maintenance)
# Out:
# (669, 669, 669, 669, 669, 669, 669, 669, 669, 669, 669, 669)

# %%
df11 = pd.DataFrame({})
df11[' Rental Price']=Price
df11['Address']=Address
df11['City']=City
df11['Bedrooms']=Bedrooms
df11['Bathrooms']=Bathrooms
df11['Total floors']=Total_floors
df11['Car parking']=Car_parking
df11['Bachelors allowed']=Bachelors_allowed   
df11['Area']=Area
df11['Furnishing']=Furnishing
df11['Type']=Type
df11['Maintenance']=Maintenance
df11
# Out:
#      Rental Price                                            Address  \
# 0        ₹ 13,000                    1 BHK FULLY FURNISHED NEW FLAT.
# 1        ₹ 13,000                            2bhk available for rent
# 2        ₹ 24,100                              2bhk near saket metro
# 3        ₹ 22,000                        1bhk builder floor in saket
# 4        ₹ 15,000                   Near tagore garden metro station
# ..            ...                                                ...
# 664       ₹ 6,000  All 1,2,3, ROOM Available for rent at Dum Dum ...
# 665       ₹ 6,000  Instant shifting available furnished house ren...
# 666       ₹ 7,000  Couples friendly ground floor new condition 1b...
# 667       ₹ 3,500  No restrictions 1Rk 2nd floor furnished rent i...
# 668      ₹ 13,000      Full furnished 1bhk flat available for rent .
#
#             City Bedrooms  Bathrooms Total floors   Car parking  \
# 0          Delhi        3          2            3             0
# ...

# %% [markdown]
# # All data in one Frame

# %%
combine= pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11], ignore_index = True)
combine
# Out:
#       Rental Price                                            Address  \
# 0         ₹ 49,000                                     House for Rent
# 1      ₹ 45,00,000                         Full Appartement for lease
# 2         ₹ 10,000            SK APARTMENT FOR RENT AT THRIPOONITHURA
# 3         ₹ 12,500  Fully furnished premium studio apartment for G...
# 4               NA                                                 NA
# ...            ...                                                ...
# 5126       ₹ 6,000  All 1,2,3, ROOM Available for rent at Dum Dum ...
# 5127       ₹ 6,000  Instant shifting available furnished house ren...
# 5128       ₹ 7,000  Couples friendly ground floor new condition 1b...
# 5129       ₹ 3,500  No restrictions 1Rk 2nd floor furnished rent i...
# 5130      ₹ 13,000      Full furnished 1bhk flat available for rent .
#
#                  City Bedrooms  Bathrooms Total floors   Car parking  \
# ...
